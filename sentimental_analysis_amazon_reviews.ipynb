# %% [markdown]
# <a href="https://colab.research.google.com/github/Harathi8522/Sentimental_Analysis-Amazon_Reviews-/blob/main/sentimental_analysis_amazon_reviews.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import statements
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import nltk
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report,ConfusionMatrixDisplay
from sklearn import naive_bayes
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.neighbors import KNeighborsClassifier
from bs4 import BeautifulSoup
from nltk.corpus import stopwords
from sklearn.ensemble import RandomForestClassifier

# %%
# reading data from sample dataset
# data = pd.read_csv('amazon_pc.csv')
data = pd.read_csv('/content/appl_1_amazon_pc (1).csv', engine='python', on_bad_lines='skip')

# %%
# print various attributes available in the dataset
data.columns
# Out:
# Index(['marketplace', 'customer_id', 'review_id', 'product_id',
#        'product_parent', 'product_title', 'product_category', 'star_rating',
#        'helpful_votes', 'total_votes', 'vine', 'verified_purchase',
#        'review_headline', 'review_body', 'review_date', 'sentiment'],
#       dtype='object')

# %%
# print properties of attributes in the dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30846 entries, 0 to 30845
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   marketplace        30846 non-null  object
#  1   customer_id        30846 non-null  int64
#  2   review_id          30846 non-null  object
#  3   product_id         30846 non-null  object
#  4   product_parent     30846 non-null  int64
#  5   product_title      30846 non-null  object
#  6   product_category   30846 non-null  object
#  7   star_rating        30846 non-null  int64
#  8   helpful_votes      30846 non-null  int64
#  9   total_votes        30846 non-null  int64
#  10  vine               30846 non-null  object
#  11  verified_purchase  30846 non-null  object
#  12  review_headline    30844 non-null  object
#  13  review_body        30842 non-null  object
#  14  review_date        30846 non-null  object
#  15  sentiment          30846 non-null  int64
# dtypes: int64(6), object(10)
# memory usage: 3.8+ MB

# %% [markdown]
# # Code for Sentimental Analysis
#
# ## Start

# %%
# adding a sentiment column to classify reviews as Positive or Negative
# Positive = 1
# Negative = 0

data['sentiment'] = np.where(data['star_rating'] == 5.0, 1,
                           np.where(data['star_rating'] == 4.0, 1, 0))

# %%
# get unique values of product title column
data["product_title"].unique()
# Out:
# array(['Fire HD 7, 7" HD Display, Wi-Fi, 8 GB'], dtype=object)

# %%
# choose a particular product for analysis
prod_hosa = data.loc[data["product_title"]=='Fire HD 7, 7" HD Display, Wi-Fi, 8 GB']
prod_hosa
# Out:
#       marketplace  customer_id       review_id  product_id  product_parent  \
# 0              US     11555559  R1QXC7AHHJBQ3O  B00IKPX4GY         2693241
# 1              US     31469372  R175VSRV6ZETOP  B00IKPYKWG         2693241
# 2              US     26843895  R2HRFF78MWGY19  B00IKPW0UA         2693241
# 3              US     19844868   R8Q39WPKYVSTX  B00LCHSHMS         2693241
# 4              US      1189852  R3RL4C8YP2ZCJL  B00IKPZ5V6         2693241
# ...           ...          ...             ...         ...             ...
# 30841          US     44834233  R366C7ARIWLN7R  B00IKPW0UA         2693241
# 30842          US     13376158  R35PL0AOCUXLU9  B00IKPYKWG         2693241
# 30843          US     40485963  R18ZJVY86AUFII  B00KC6XV58         2693241
# 30844          US     33485035  R36QVLQXMCZRSJ  B00IKPYKWG         2693241
# 30845          US      7015231  R1MWVQUDBUADGE  B00IKPYKWG         2693241
#
#                                product_title product_category  star_rating  \
# 0      Fire HD 7, 7" HD Display, Wi-Fi, 8 GB               PC            5
# 1      Fire HD 7, 7" HD Display, Wi-Fi, 8 GB               PC            3
# 2      Fire HD 7, 7" HD Display, Wi-Fi, 8 GB               PC            5
# 3      Fire HD 7, 7" HD Display, Wi-Fi, 8 GB               PC            4
# 4      Fire HD 7, 7" HD Display, Wi-Fi, 8 GB               PC            5
# ...                                      ...              ...          ...
# 30841  Fire HD 7, 7" HD Display, Wi-Fi, 8 GB               PC            5
# 30842  Fire HD 7, 7" HD Display, Wi-Fi, 8 GB               PC            5
# 30843  Fire HD 7, 7" HD Display, Wi-Fi, 8 GB               PC            5
# 30844  Fire HD 7, 7" HD Display, Wi-Fi, 8 GB               PC            4
# 30845  Fire HD 7, 7" HD Display, Wi-Fi, 8 GB               PC            5
#
#        helpful_votes  total_votes vine verified_purchase  \
# 0                  0            0    N                 Y
# 1                  0            0    N                 N
# 2                  0            0    N                 Y
# 3                  0            0    N                 N
# 4                  0            0    N                 Y
# ...              ...          ...  ...               ...
# 30841           3720         3875    N                 Y
# 30842           2716         2849    N                 Y
# 30843           1525         1629    N                 Y
# 30844            143          163    N                 Y
# 30845              2           10    N                 N
#
#                                          review_headline  \
# 0                                             Five Stars
# 1      Lots of ads Slow processing speed Occasionally...
# 2                                Well thought out device
# 3      Not all apps/games we were looking forward to ...
# 4                                             Five Stars
# ...                                                  ...
# 30841  A great upgrade for me from an older Kindle Fire!
# 30842                               Great Value for $139
# 30843                   Even grandma has it figured out!
# 30844                        The Honda Accord of Tablets
# 30845                                    won't regret it
#
#                                              review_body review_date  \
# 0                                          Great love it  2015-08-31
# 1      Lots of ads<br />Slow processing speed<br />Oc...  2015-08-31
# 2      Excellent unit.  The versatility of this table...  2015-08-31
# 3      I bought this on Amazon Prime so I ended up bu...  2015-08-31
# 4      All Amazon products continue to meet my expect...  2015-08-31
# ...                                                  ...         ...
# 30841  [[VIDEOID:moP3B6GS5RL8LY]]I purchased the orig...  2014-10-03
# 30842  I'm writing this review with the benefit of be...  2014-10-03
# 30843  I purchased this Kindle for my grandma, becaus...  2014-10-03
# 30844  I bought my tablet Fire HD 7 at Best Buy on th...  2014-10-03
# 30845  Am impressive piece of hardware for the $. No ...  2014-10-03
#
#        sentiment
# 0              1
# 1              0
# 2              1
# 3              1
# 4              1
# ...          ...
# 30841          1
# 30842          1
# 30843          1
# 30844          1
# 30845          1
#
# [30846 rows x 16 columns]

# %%
# #split data-set to train and test

X = prod_hosa['review_body']
Y = prod_hosa['sentiment']

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state=42)

# %%
# function to remove html elements from the reviews
def removeHTML(raw_text):
    clean_HTML = BeautifulSoup(raw_text, 'lxml').get_text()
    return clean_HTML

# %%
# function to remove special characters and numbers from the reviews4961
def removeSpecialChar(raw_text):
    clean_SpecialChar = re.sub("[^a-zA-Z]", " ", raw_text)
    return clean_SpecialChar

# %%
# function to convert all reviews into lower case
def toLowerCase(raw_text):
    clean_LowerCase = raw_text.lower().split()
    return( " ".join(clean_LowerCase))

# %%
# function to remove stop words from the reviews
def removeStopWords(raw_text):
    stops = set(stopwords.words("english"))
    # Ensure raw_text is a string before splitting
    words = [w for w in str(raw_text).split() if w not in stops]
    return " ".join(words)

# %%
# X_training clean set
X_train_cleaned = []

for val in X_train.fillna(''): # Handle NaN values by replacing them with empty strings
    val = removeHTML(val)
    val = removeSpecialChar(val)
    val = toLowerCase(val)
    val = removeStopWords(val)
    X_train_cleaned.append(val)

# Display some cleaned samples to inspect
print("Sample of cleaned training data:")
for i in range(min(5, len(X_train_cleaned))):
    print(f"Sample {i+1}: {X_train_cleaned[i]}")
# Out:
# Sample of cleaned training data:
# Sample 1: love
# Sample 2: love fire hd
# Sample 3: like fire problems using books know press side get first part book
# Sample 4: nice tablet allow google play amazon stopped fix called rooting use play store
# Sample 5: love

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
# X_testing clean set
X_test_cleaned = []

for val in X_test.fillna(''): # Handle NaN values by replacing them with empty strings
    val = removeHTML(val)
    val = removeSpecialChar(val)
    val = toLowerCase(val)
    val = removeStopWords(val)
    X_test_cleaned.append(val)

# %%
# Convert a collection of raw documents to a matrix of TF-IDF features. This is required so as to train the model using features instead of
# raw strings.
tvec = TfidfVectorizer(use_idf=True,
strip_accents='ascii',
min_df=1)

X_train_tvec = tvec.fit_transform(X_train_cleaned)

# %%
# Convert a collection of raw documents to a matrix of TF-IDF features. This is required so as to train the model using features instead of
# raw strings.
# tvec = TfidfVectorizer(use_idf=True,
# strip_accents='ascii')

# X_train_tvec = tvec.fit_transform(X_train_cleaned)
X_test_tvec = tvec.transform(X_test_cleaned)

# %%
# Support Vector Classifier model
svr_lin = LinearSVC(multi_class='ovr',C=1.0,loss='squared_hinge', dual=False)
svr_lin.fit(X_train_tvec, Y_train)
# Out:
# LinearSVC(dual=False)

# %%
# Predict using training and testing data and display the accuracy, f-1 score, precision for Positive and Negative Sentiment Classifiers
svr_lin_predictions = svr_lin.predict(tvec.transform(X_test_cleaned))
report = classification_report(Y_test,svr_lin_predictions, output_dict=True)
data_report = pd.DataFrame(report).transpose().round(2)
cm = sns.light_palette("yellow", as_cmap=True)
data_report.style.background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_63794_row0_col0, #T_63794_row0_col1, #T_63794_row0_col2, #T_63794_row2_col3 {
#   background-color: #f2f2dd;
#   color: #000000;
# }
# #T_63794_row0_col3 {
#   background-color: #f4f4b9;
#   color: #000000;
# }
# #T_63794_row1_col0, #T_63794_row1_col1, #T_63794_row1_col2, #T_63794_row3_col3, #T_63794_row4_col3 {
#   background-color: #ffff00;
#   color: #000000;
# }
# #T_63794_row1_col3, #T_63794_row2_col1, #T_63794_row4_col1 {
#   background-color: #fdfd24;
#   color: #000000;
# }
# #T_63794_row2_col0 {
#   background-color: #fefe17;
#   color: #000000;
# }
# #T_63794_row2_col2 {
#   background-color: #fdfd1f;
#   color: #000000;
# }
# #T_63794_row3_col0 {
#   background-color: #f9f969;
#   color: #000000;
# }
# #T_63794_row3_col1, #T_63794_row3_col2 {
#   background-color: #f9f96e;
#   color: #000000;
# }
# #T_63794_row4_col0 {
#   background-color: #fdfd23;
#   color: #000000;
# }
# #T_63794_row4_col2 {
#   background-color: #fdfd27;
#   color: #000000;
# }
# </style>
# <table id="T_63794" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_63794_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_63794_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_63794_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_63794_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_63794_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_63794_row0_col0" class="data row0 col0" >0.730000</td>
#       <td id="T_63794_row0_col1" class="data row0 col1" >0.600000</td>
#       <td id="T_63794_row0_col2" class="data row0 col2" >0.660000</td>
#       <td id="T_63794_row0_col3" class="data row0 col3" >1018.000000</td>
#     </tr>
#     <tr>
#       <th id="T_63794_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_63794_row1_col0" class="data row1 col0" >0.920000</td>
#       <td id="T_63794_row1_col1" class="data row1 col1" >0.960000</td>
#       <td id="T_63794_row1_col2" class="data row1 col2" >0.940000</td>
#       <td id="T_63794_row1_col3" class="data row1 col3" >5152.000000</td>
#     </tr>
#     <tr>
#       <th id="T_63794_level0_row2" class="row_heading level0 row2" >accuracy</th>
#       <td id="T_63794_row2_col0" class="data row2 col0" >0.900000</td>
#       <td id="T_63794_row2_col1" class="data row2 col1" >0.900000</td>
#       <td id="T_63794_row2_col2" class="data row2 col2" >0.900000</td>
#       <td id="T_63794_row2_col3" class="data row2 col3" >0.900000</td>
#     </tr>
#     <tr>
#       <th id="T_63794_level0_row3" class="row_heading level0 row3" >macro avg</th>
#       <td id="T_63794_row3_col0" class="data row3 col0" >0.830000</td>
#       <td id="T_63794_row3_col1" class="data row3 col1" >0.780000</td>
#       <td id="T_63794_row3_col2" class="data row3 col2" >0.800000</td>
#       <td id="T_63794_row3_col3" class="data row3 col3" >6170.000000</td>
#     </tr>
#     <tr>
#       <th id="T_63794_level0_row4" class="row_heading level0 row4" >weighted avg</th>
#       <td id="T_63794_row4_col0" class="data row4 col0" >0.890000</td>
#       <td id="T_63794_row4_col1" class="data row4 col1" >0.900000</td>
#       <td id="T_63794_row4_col2" class="data row4 col2" >0.890000</td>
#       <td id="T_63794_row4_col3" class="data row4 col3" >6170.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# confusion matrix
svr_lin_predictions=svr_lin.predict(tvec.transform(X_test_cleaned))
ax= plt.subplot()
cm=confusion_matrix(Y_test,svr_lin_predictions)
sns.heatmap(cm, annot=True, fmt='g', ax=ax,cmap='Greens');
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels');
ax.set_title('Confusion Matrix');
ax.xaxis.set_ticklabels(['negative', 'positive']); ax.yaxis.set_ticklabels(['negative', 'positive']);

# %%
# testing the model with sample 'Negative' review
demo_review = np.array(['three days of use and it broke very disappointed in this product it worked perfectly for exactly three days and could not be resuscitated it was very inexpensive so i did not want to pay half again the price to ship it back for an exchange so the company would do nothing when they sent me an inquiry as to product satisfaction'])
demo_review_X_test = tvec.transform(demo_review)
print(svr_lin.predict(demo_review_X_test))

# expected output = 0 (Negative)
# actual output = 0 (Negative)
# Out:
# [0]

# %%
# testing the model with sample 'Positive' review
demo_review_2 = np.array(['Excellent product. Works well and performs as expected.'])
demo_review_X_test_2 = tvec.transform(demo_review_2)
print(svr_lin.predict(demo_review_X_test_2))

# expected output = 1 (Positive)
# actual output = 1 (Positive)
# Out:
# [1]

# %%
# Random Forest model
random_forest = RandomForestClassifier()
random_forest.fit(X_train_tvec, Y_train)
# Out:
# RandomForestClassifier()

# %%
# Predict using training and testing data and display the accuracy, f-1 score, precision for Positive and Negative Sentiment Classifiers
ranfrst_predictions = random_forest.predict(tvec.transform(X_test_cleaned))
report = classification_report(Y_test,ranfrst_predictions, output_dict=True)
data_report = pd.DataFrame(report).transpose().round(2)
cm = sns.light_palette("red", as_cmap=True)
data_report.style.background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_6c804_row0_col0, #T_6c804_row0_col1, #T_6c804_row0_col2, #T_6c804_row2_col3 {
#   background-color: #f3f0f0;
#   color: #000000;
# }
# #T_6c804_row0_col3 {
#   background-color: #f5c8c8;
#   color: #000000;
# }
# #T_6c804_row1_col0, #T_6c804_row1_col1, #T_6c804_row1_col2, #T_6c804_row2_col0, #T_6c804_row3_col3, #T_6c804_row4_col3 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# #T_6c804_row1_col3, #T_6c804_row4_col0 {
#   background-color: #fd2828;
#   color: #f1f1f1;
# }
# #T_6c804_row2_col1, #T_6c804_row4_col1 {
#   background-color: #fd2424;
#   color: #f1f1f1;
# }
# #T_6c804_row2_col2 {
#   background-color: #fe1717;
#   color: #f1f1f1;
# }
# #T_6c804_row3_col0, #T_6c804_row3_col1 {
#   background-color: #f97878;
#   color: #f1f1f1;
# }
# #T_6c804_row3_col2 {
#   background-color: #f97575;
#   color: #f1f1f1;
# }
# #T_6c804_row4_col2 {
#   background-color: #fd2323;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6c804" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6c804_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_6c804_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_6c804_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_6c804_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6c804_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6c804_row0_col0" class="data row0 col0" >0.830000</td>
#       <td id="T_6c804_row0_col1" class="data row0 col1" >0.380000</td>
#       <td id="T_6c804_row0_col2" class="data row0 col2" >0.520000</td>
#       <td id="T_6c804_row0_col3" class="data row0 col3" >1018.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6c804_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6c804_row1_col0" class="data row1 col0" >0.890000</td>
#       <td id="T_6c804_row1_col1" class="data row1 col1" >0.980000</td>
#       <td id="T_6c804_row1_col2" class="data row1 col2" >0.930000</td>
#       <td id="T_6c804_row1_col3" class="data row1 col3" >5152.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6c804_level0_row2" class="row_heading level0 row2" >accuracy</th>
#       <td id="T_6c804_row2_col0" class="data row2 col0" >0.890000</td>
#       <td id="T_6c804_row2_col1" class="data row2 col1" >0.890000</td>
#       <td id="T_6c804_row2_col2" class="data row2 col2" >0.890000</td>
#       <td id="T_6c804_row2_col3" class="data row2 col3" >0.890000</td>
#     </tr>
#     <tr>
#       <th id="T_6c804_level0_row3" class="row_heading level0 row3" >macro avg</th>
#       <td id="T_6c804_row3_col0" class="data row3 col0" >0.860000</td>
#       <td id="T_6c804_row3_col1" class="data row3 col1" >0.680000</td>
#       <td id="T_6c804_row3_col2" class="data row3 col2" >0.730000</td>
#       <td id="T_6c804_row3_col3" class="data row3 col3" >6170.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6c804_level0_row4" class="row_heading level0 row4" >weighted avg</th>
#       <td id="T_6c804_row4_col0" class="data row4 col0" >0.880000</td>
#       <td id="T_6c804_row4_col1" class="data row4 col1" >0.890000</td>
#       <td id="T_6c804_row4_col2" class="data row4 col2" >0.870000</td>
#       <td id="T_6c804_row4_col3" class="data row4 col3" >6170.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# confusion matrix
ranfrst_predictions=random_forest.predict(tvec.transform(X_test_cleaned))
ax= plt.subplot()
cm=confusion_matrix(Y_test,ranfrst_predictions)
sns.heatmap(cm, annot=True, fmt='g', ax=ax,cmap='Oranges');
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels');
ax.set_title('Confusion Matrix');
ax.xaxis.set_ticklabels(['negative', 'positive']); ax.yaxis.set_ticklabels(['negative', 'positive']);

# %%
# testing the model with sample 'Negative' review
demo_review = np.array(['Do not buy. Fake Product.'])
demo_review_X_test = tvec.transform(demo_review)
print(random_forest.predict(demo_review_X_test))

# expected output = 0 (Negative)
# actual output = 0 (Negative)
# Out:
# [1]

# %%
# testing the model with sample 'Positive' review
demo_review_2 = np.array(['Original Product. Great Performance.'])
demo_review_X_test_2 = tvec.transform(demo_review_2)
print(random_forest.predict(demo_review_X_test_2))

# expected output = 1 (Positive)
# actual output = 1 (Positive)
# Out:
# [1]

# %%
# K-Nearest Neighbor model
knn = KNeighborsClassifier(n_neighbors=5,metric='minkowski',p=2)
knn.fit(X_train_tvec, Y_train)
# Out:
# KNeighborsClassifier()

# %%
# Predict using training and testing data and display the accuracy, f-1 score, precision for Positive and Negative Sentiment Classifiers
knn_predictions = knn.predict(tvec.transform(X_test_cleaned))
report = classification_report(Y_test,knn_predictions, output_dict=True)
data_report = pd.DataFrame(report).transpose().round(2)
cm = sns.light_palette("gray", as_cmap=True)
data_report.style.background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_a234f_row0_col0, #T_a234f_row0_col1, #T_a234f_row0_col2, #T_a234f_row2_col3 {
#   background-color: #f1f1f1;
#   color: #000000;
# }
# #T_a234f_row0_col3 {
#   background-color: #dedede;
#   color: #000000;
# }
# #T_a234f_row1_col0, #T_a234f_row1_col1, #T_a234f_row1_col2, #T_a234f_row2_col0, #T_a234f_row3_col3, #T_a234f_row4_col3 {
#   background-color: #808080;
#   color: #f1f1f1;
# }
# #T_a234f_row1_col3, #T_a234f_row2_col1, #T_a234f_row4_col1, #T_a234f_row4_col2 {
#   background-color: #939393;
#   color: #f1f1f1;
# }
# #T_a234f_row2_col2 {
#   background-color: #898989;
#   color: #f1f1f1;
# }
# #T_a234f_row3_col0 {
#   background-color: #b5b5b5;
#   color: #000000;
# }
# #T_a234f_row3_col1, #T_a234f_row3_col2 {
#   background-color: #b8b8b8;
#   color: #000000;
# }
# #T_a234f_row4_col0 {
#   background-color: #949494;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a234f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a234f_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_a234f_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_a234f_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_a234f_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a234f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a234f_row0_col0" class="data row0 col0" >0.670000</td>
#       <td id="T_a234f_row0_col1" class="data row0 col1" >0.040000</td>
#       <td id="T_a234f_row0_col2" class="data row0 col2" >0.080000</td>
#       <td id="T_a234f_row0_col3" class="data row0 col3" >1018.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a234f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a234f_row1_col0" class="data row1 col0" >0.840000</td>
#       <td id="T_a234f_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_a234f_row1_col2" class="data row1 col2" >0.910000</td>
#       <td id="T_a234f_row1_col3" class="data row1 col3" >5152.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a234f_level0_row2" class="row_heading level0 row2" >accuracy</th>
#       <td id="T_a234f_row2_col0" class="data row2 col0" >0.840000</td>
#       <td id="T_a234f_row2_col1" class="data row2 col1" >0.840000</td>
#       <td id="T_a234f_row2_col2" class="data row2 col2" >0.840000</td>
#       <td id="T_a234f_row2_col3" class="data row2 col3" >0.840000</td>
#     </tr>
#     <tr>
#       <th id="T_a234f_level0_row3" class="row_heading level0 row3" >macro avg</th>
#       <td id="T_a234f_row3_col0" class="data row3 col0" >0.760000</td>
#       <td id="T_a234f_row3_col1" class="data row3 col1" >0.520000</td>
#       <td id="T_a234f_row3_col2" class="data row3 col2" >0.500000</td>
#       <td id="T_a234f_row3_col3" class="data row3 col3" >6170.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a234f_level0_row4" class="row_heading level0 row4" >weighted avg</th>
#       <td id="T_a234f_row4_col0" class="data row4 col0" >0.810000</td>
#       <td id="T_a234f_row4_col1" class="data row4 col1" >0.840000</td>
#       <td id="T_a234f_row4_col2" class="data row4 col2" >0.770000</td>
#       <td id="T_a234f_row4_col3" class="data row4 col3" >6170.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# confusion matrix
knn_predictions=knn.predict(tvec.transform(X_test_cleaned))
ax= plt.subplot()
cm=confusion_matrix(Y_test,knn_predictions)
sns.heatmap(cm, annot=True, fmt='g', ax=ax,cmap='Reds');
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels');
ax.set_title('Confusion Matrix');
ax.xaxis.set_ticklabels(['negative', 'positive']); ax.yaxis.set_ticklabels(['negative', 'positive']);

# %%
# testing the model with sample 'Negative' review
demo_review = np.array(['Bad product. Very much disappointed'])
demo_review_X_test = tvec.transform(demo_review)
print(knn.predict(demo_review_X_test))

# expected output = 0 (Negative)
# actual output = 0 (Negative)
# Out:
# [0]

# %%
# testing the model with sample 'Positive' review
demo_review_2 = np.array(['Excellent product. Works well and performs as expected.'])
demo_review_X_test_2 = tvec.transform(demo_review_2)
print(knn.predict(demo_review_X_test_2))

# expected output = 1 (Positive)
# actual output = 1 (Positive)
# Out:
# [1]

# %%
# Logistic regression model
lr = LogisticRegression()
lr.fit(X_train_tvec, Y_train)
# Out:
# LogisticRegression()

# %%
# Predict using training and testing data and display the accuracy, f-1 score, precision for Positive and Negative Sentiment Classifiers
lr_predictions = lr.predict(tvec.transform(X_test_cleaned))
report = classification_report(Y_test,lr_predictions, output_dict=True)
data_report = pd.DataFrame(report).transpose().round(2)
cm = sns.light_palette("purple", as_cmap=True)
data_report.style.background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_a7e0e_row0_col0, #T_a7e0e_row0_col1, #T_a7e0e_row0_col2, #T_a7e0e_row2_col3 {
#   background-color: #f3f0f3;
#   color: #000000;
# }
# #T_a7e0e_row0_col3 {
#   background-color: #e0c8e0;
#   color: #000000;
# }
# #T_a7e0e_row1_col0, #T_a7e0e_row1_col1, #T_a7e0e_row1_col2, #T_a7e0e_row3_col3, #T_a7e0e_row4_col3 {
#   background-color: #800080;
#   color: #f1f1f1;
# }
# #T_a7e0e_row1_col3 {
#   background-color: #932793;
#   color: #f1f1f1;
# }
# #T_a7e0e_row2_col0 {
#   background-color: #902290;
#   color: #f1f1f1;
# }
# #T_a7e0e_row2_col1, #T_a7e0e_row4_col1 {
#   background-color: #932893;
#   color: #f1f1f1;
# }
# #T_a7e0e_row2_col2 {
#   background-color: #902190;
#   color: #f1f1f1;
# }
# #T_a7e0e_row3_col0 {
#   background-color: #ba78ba;
#   color: #f1f1f1;
# }
# #T_a7e0e_row3_col1 {
#   background-color: #b875b8;
#   color: #f1f1f1;
# }
# #T_a7e0e_row3_col2 {
#   background-color: #b774b7;
#   color: #f1f1f1;
# }
# #T_a7e0e_row4_col0 {
#   background-color: #983398;
#   color: #f1f1f1;
# }
# #T_a7e0e_row4_col2 {
#   background-color: #942994;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a7e0e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a7e0e_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_a7e0e_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_a7e0e_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_a7e0e_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a7e0e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a7e0e_row0_col0" class="data row0 col0" >0.780000</td>
#       <td id="T_a7e0e_row0_col1" class="data row0 col1" >0.560000</td>
#       <td id="T_a7e0e_row0_col2" class="data row0 col2" >0.650000</td>
#       <td id="T_a7e0e_row0_col3" class="data row0 col3" >1018.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a7e0e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a7e0e_row1_col0" class="data row1 col0" >0.920000</td>
#       <td id="T_a7e0e_row1_col1" class="data row1 col1" >0.970000</td>
#       <td id="T_a7e0e_row1_col2" class="data row1 col2" >0.940000</td>
#       <td id="T_a7e0e_row1_col3" class="data row1 col3" >5152.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a7e0e_level0_row2" class="row_heading level0 row2" >accuracy</th>
#       <td id="T_a7e0e_row2_col0" class="data row2 col0" >0.900000</td>
#       <td id="T_a7e0e_row2_col1" class="data row2 col1" >0.900000</td>
#       <td id="T_a7e0e_row2_col2" class="data row2 col2" >0.900000</td>
#       <td id="T_a7e0e_row2_col3" class="data row2 col3" >0.900000</td>
#     </tr>
#     <tr>
#       <th id="T_a7e0e_level0_row3" class="row_heading level0 row3" >macro avg</th>
#       <td id="T_a7e0e_row3_col0" class="data row3 col0" >0.850000</td>
#       <td id="T_a7e0e_row3_col1" class="data row3 col1" >0.770000</td>
#       <td id="T_a7e0e_row3_col2" class="data row3 col2" >0.800000</td>
#       <td id="T_a7e0e_row3_col3" class="data row3 col3" >6170.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a7e0e_level0_row4" class="row_heading level0 row4" >weighted avg</th>
#       <td id="T_a7e0e_row4_col0" class="data row4 col0" >0.890000</td>
#       <td id="T_a7e0e_row4_col1" class="data row4 col1" >0.900000</td>
#       <td id="T_a7e0e_row4_col2" class="data row4 col2" >0.890000</td>
#       <td id="T_a7e0e_row4_col3" class="data row4 col3" >6170.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# confusion matrix
lr_predictions=lr.predict(tvec.transform(X_test_cleaned))
ax= plt.subplot()
cm=confusion_matrix(Y_test,lr_predictions)
sns.heatmap(cm, annot=True, fmt='g', ax=ax,cmap='Reds');
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels');
ax.set_title('Confusion Matrix');
ax.xaxis.set_ticklabels(['negative', 'positive']); ax.yaxis.set_ticklabels(['negative', 'positive']);

# %%
# testing the model with sample 'Negative' review
demo_review = np.array(['Poor quality. Faulty device.'])
demo_review_X_test = tvec.transform(demo_review)
print(lr.predict(demo_review_X_test))

# expected output = 0 (Negative)
# actual output = 0 (Negative)
# Out:
# [0]

# %%
# testing the model with sample 'Positive' review
demo_review_2 = np.array(['Best product.'])
demo_review_X_test_2 = tvec.transform(demo_review_2)
print(lr.predict(demo_review_X_test_2))

# expected output = 1 (Positive)
# actual output = 1 (Positive)
# Out:
# [1]

# %%
# Naive Bayes model
nbm = naive_bayes.MultinomialNB()
nbm.fit(X_train_tvec, Y_train)
# Out:
# MultinomialNB()

# %%
# Predict using training and testing data and display the accuracy, f-1 score, precision for Positive and Negative Sentiment Classifiers
nbm_predictions = nbm.predict(tvec.transform(X_test_cleaned))
report = classification_report(Y_test,nbm_predictions, output_dict=True)
data_report = pd.DataFrame(report).transpose().round(2)
cm = sns.light_palette("blue", as_cmap=True)
data_report.style.background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_47e39_row0_col0, #T_47e39_row1_col1, #T_47e39_row1_col2, #T_47e39_row3_col3, #T_47e39_row4_col3 {
#   background-color: #0000ff;
#   color: #f1f1f1;
# }
# #T_47e39_row0_col1, #T_47e39_row0_col2, #T_47e39_row1_col0, #T_47e39_row2_col0, #T_47e39_row2_col3 {
#   background-color: #f0f0f3;
#   color: #000000;
# }
# #T_47e39_row0_col3 {
#   background-color: #c9c9f5;
#   color: #000000;
# }
# #T_47e39_row1_col3 {
#   background-color: #2828fd;
#   color: #f1f1f1;
# }
# #T_47e39_row2_col1, #T_47e39_row4_col1 {
#   background-color: #2929fd;
#   color: #f1f1f1;
# }
# #T_47e39_row2_col2 {
#   background-color: #1919fe;
#   color: #f1f1f1;
# }
# #T_47e39_row3_col0 {
#   background-color: #5050fb;
#   color: #f1f1f1;
# }
# #T_47e39_row3_col1 {
#   background-color: #7979f9;
#   color: #f1f1f1;
# }
# #T_47e39_row3_col2 {
#   background-color: #7676f9;
#   color: #f1f1f1;
# }
# #T_47e39_row4_col0 {
#   background-color: #a0a0f7;
#   color: #f1f1f1;
# }
# #T_47e39_row4_col2 {
#   background-color: #2525fd;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_47e39" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_47e39_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_47e39_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_47e39_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_47e39_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_47e39_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_47e39_row0_col0" class="data row0 col0" >0.890000</td>
#       <td id="T_47e39_row0_col1" class="data row0 col1" >0.200000</td>
#       <td id="T_47e39_row0_col2" class="data row0 col2" >0.330000</td>
#       <td id="T_47e39_row0_col3" class="data row0 col3" >1018.000000</td>
#     </tr>
#     <tr>
#       <th id="T_47e39_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_47e39_row1_col0" class="data row1 col0" >0.860000</td>
#       <td id="T_47e39_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_47e39_row1_col2" class="data row1 col2" >0.920000</td>
#       <td id="T_47e39_row1_col3" class="data row1 col3" >5152.000000</td>
#     </tr>
#     <tr>
#       <th id="T_47e39_level0_row2" class="row_heading level0 row2" >accuracy</th>
#       <td id="T_47e39_row2_col0" class="data row2 col0" >0.860000</td>
#       <td id="T_47e39_row2_col1" class="data row2 col1" >0.860000</td>
#       <td id="T_47e39_row2_col2" class="data row2 col2" >0.860000</td>
#       <td id="T_47e39_row2_col3" class="data row2 col3" >0.860000</td>
#     </tr>
#     <tr>
#       <th id="T_47e39_level0_row3" class="row_heading level0 row3" >macro avg</th>
#       <td id="T_47e39_row3_col0" class="data row3 col0" >0.880000</td>
#       <td id="T_47e39_row3_col1" class="data row3 col1" >0.600000</td>
#       <td id="T_47e39_row3_col2" class="data row3 col2" >0.630000</td>
#       <td id="T_47e39_row3_col3" class="data row3 col3" >6170.000000</td>
#     </tr>
#     <tr>
#       <th id="T_47e39_level0_row4" class="row_heading level0 row4" >weighted avg</th>
#       <td id="T_47e39_row4_col0" class="data row4 col0" >0.870000</td>
#       <td id="T_47e39_row4_col1" class="data row4 col1" >0.860000</td>
#       <td id="T_47e39_row4_col2" class="data row4 col2" >0.830000</td>
#       <td id="T_47e39_row4_col3" class="data row4 col3" >6170.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# confusion matrix
nbm_predictions=nbm.predict(tvec.transform(X_test_cleaned))
ax= plt.subplot()
cm=confusion_matrix(Y_test,nbm_predictions)
sns.heatmap(cm, annot=True, fmt='g', ax=ax,cmap='Purples');
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels');
ax.set_title('Confusion Matrix');
ax.xaxis.set_ticklabels(['negative', 'positive']); ax.yaxis.set_ticklabels(['negative', 'positive']);

# %%
# testing the model with sample 'Negative' review
demo_review = np.array(['Defective. Bad. Stopped working after one day use'])
demo_review_X_test = tvec.transform(demo_review)
print(nbm.predict(demo_review_X_test))

# expected output = 0 (Negative)
# actual output = 0 (Negative)
# Out:
# [0]

# %%
# testing the model with sample 'Positive' review
demo_review_2 = np.array(['Good product. highly recommend buying.'])
demo_review_X_test_2 = tvec.transform(demo_review_2)
print(nbm.predict(demo_review_X_test_2))

# expected output = 1 (Positive)
# actual output = 1 (Positive)
# Out:
# [1]

# %% [markdown]
# # Code for Sentimental Analysis
#
# # Ends
